# %%
import fxcmpy
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import datetime as dt
import time
# %matplotlib inline
from matplotlib import style
style.use('ggplot')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
con=fxcmpy.fxcmpy(config_file = 'fxcm.cfg')
print(con.get_instruments_for_candles())
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-fbf4db3bf934> in <module>()
# ----> 1 con=fxcmpy.fxcmpy(config_file = 'fxcm.cfg')
#       2 print(con.get_instruments_for_candles())
#
# ~\Anaconda3\lib\site-packages\fxcmpy\fxcmpy.py in __init__(self, access_token, config_file, log_file, log_level, server, proxy_url, proxy_port, proxy_type)
#     105             if len(found_config_file) == 0:
#     106                 raise IOError("Can not open config file: {0}"
# --> 107                     .format(config_file))
#     108             if 'FXCM' not in config.sections():
#     109                 raise ValueError("Can not find section [FXCM] in {0}"
#
# OSError: Can not open config file: fxcm.cfg

# %%
# token = '1a5119225ed0a512e50f2c1df26952208792e06a'
symbol = 'EUR/USD'
timeframe = "m30"    # (m1,m5,m15,m30,H1,H2,H3,H4,H6,H8,D1,W1,M1)
close_on_opposing_signal = True
amount = 50
stop = -10
limit = 30

# %%
# Global Variables
pricedata = None
numberofcandles = 100

# %%
def Prepare():
    global pricedata
    
    print("Requesting Initial Price Data...")
    pricedata = con.get_candles(symbol, period=timeframe, number=numberofcandles)
    print(pricedata.tail())
    print("Initial Price Data Received..")
# Get latest close bar prices and run Update() function every close of bar/candle
def StrategyHeartBeat():
    while True:
        currenttime = dt.datetime.now()
        if timeframe == "m1" and currenttime.second == 0 and GetLatestPriceData():
            Update()
        elif timeframe == "m5" and currenttime.second == 0 and currenttime.minute % 5 == 0 and GetLatestPriceData(): 
            Update()
            time.sleep(240)
        elif timeframe == "m15" and currenttime.second == 0 and currenttime.minute % 15 == 0 and GetLatestPriceData(): 
            Update()
            time.sleep(840)
        elif timeframe == "m30" and currenttime.second == 0 and currenttime.minute % 30 == 0 and GetLatestPriceData():
            Update()
            time.sleep(1740)
        elif currenttime.second == 0 and currenttime.minute == 0 and GetLatestPriceData():
            Update()
            time.sleep(3540)
        time.sleep(1)

def GetLatestPriceData():
    global pricedata
    # Normal operation will update pricedata on first attempt
    new_pricedata = con.get_candles(symbol, period=timeframe, number=numberofcandles)
    if new_pricedata.index.values[len(new_pricedata.index.values)-1] != pricedata.index.values[len(pricedata.index.values)-1]:
        pricedata= new_pricedata
        return True
        
    counter = 0
    # If data is not available on first attempt, try up to 3 times to update pricedata
    while new_pricedata.index.values[len(new_pricedata.index.values)-1] == pricedata.index.values[len(pricedata.index.values)-1] and counter < 3:
        print("No updated prices found, trying again in 10 seconds...")
        counter+=1
        time.sleep(10)
        new_pricedata = con.get_candles(symbol, period=timeframe, number=numberofcandles)
    if new_pricedata.index.values[len(new_pricedata.index.values)-1] != pricedata.index.values[len(pricedata.index.values)-1]:
        pricedata = new_pricedata
        return True
    else:
        return False

# %%
def labelChange(df, colname):
    df['changeDetected'] = 0
    sign = 0
    df.reset_index(drop=False, inplace=True)
    for i, row in df.iterrows():
        sign_l = np.sign(row['slope'])
#         print("Previous sign: {}  and current sign: {}".format(sign, sign_l))
        if sign_l>=0 and sign<=0:
            sign = sign_l
            df['changeDetected'].iloc[i:i+1,] = 1
        elif sign_l<=0 and sign>=0:
            sign = sign_l
            df['changeDetected'].iloc[i:i+1,] = -1
        else:
            df['changeDetected'].iloc[i:i+1,] = 0
    return df

def getSlope(x):
    n = len(x)
    y = np.arange(1, n+1, 1)
    slope,_ = np.polyfit(x, y, deg=1)
    return slope

# %%
def Update():
    print(str(dt.datetime.now()) + "    " + timeframe + " Bar Closed - Running Update Function...")

#     # Calculate Indicators
#     iFastSMA = sma(pricedata['bidclose'], fast_sma_periods)
#     iSlowSMA = sma(pricedata['bidclose'], slow_sma_periods)
    
    data = pd.DataFrame(pricedata[['askclose', 'bidclose']].mean(axis=1), columns=['mid_close'])
    data['mid_close_mva4'] = data['mid_close'].rolling(4).mean()
    data['mid_close_mva5'] = data['mid_close'].rolling(5).mean()
    data['slope'] = data.mid_close_mva4.rolling(6).apply(getSlope)
    data.dropna(axis=0, inplace=True)
    data = labelChange(df=data, colname='slope')
    data.set_index(data["date"], inplace=True)
    print(data.tail())
#     # Print Price/Indicators
#     print("Close Price: " + str(pricedata['bidclose'][len(pricedata)-1]))
#     print("Fast SMA: " + str(iFastSMA[len(iFastSMA)-1]))
#     print("Slow SMA: " + str(iSlowSMA[len(iSlowSMA)-1]))
    
    # TRADING LOGIC data['mid_close'][9:].values[0]
    # If Fast SMA crosses over Slow SMA, Open Buy Trade
    if data['changeDetected'][data.shape[0]-1:].values[0]==1:
        print("  BUY SIGNAL!")
        if close_on_opposing_signal and countOpenTrades("S") > 0:
            print(" Closing Sell Trade(s)...")
            exit("S")
        print("  Opening Buy Trade...")
        enter("B")
    # If Fast SMA crosses under Slow SMA, Open Sell Trade
    if data['changeDetected'][data.shape[0]-1:].values[0]==-1:
        print("  SELL SIGNAL!")
        if close_on_opposing_signal and countOpenTrades("B") > 0:
            print("  Closing Buy Trade(s)...")
            exit("B")
        print("  Opening Sell Trade...")
        enter("S")
        
    print(str(dt.datetime.now()) + "	 " + timeframe + " Update Function Completed.\n")

# This function places a market order in the direction BuySell, "B" = Buy, "S" = Sell, uses symbol, amount, stop, limit
def enter(BuySell):
    direction = True;
    if BuySell == "S":
        direction = False;
    try:
        opentrade = con.open_trade(symbol=symbol, is_buy=direction,amount=amount,time_in_force='GTC', order_type='AtMarket',is_in_pips=True,limit=limit, stop=stop)
    except Exception as e:
        print("  Error Opening Trade.")
        print(e)
    else:
        print("  Trade Opened Successfully.")

# This function closes all positions that are in the direction BuySell, "B" = Close All Buy Positions, "S" = Close All Sell Positions, uses symbol
def exit(BuySell=None):
    openpositions = con.get_open_positions(kind='list')
    isbuy = True
    if BuySell == "S":
        isbuy = False
    for position in openpositions:
        if position['currency'] == symbol:
            if BuySell is None or position['isBuy'] == isbuy:
                print("  Closing tradeID: " + position['tradeId'])
                try:
                    closetrade = con.close_trade(trade_id=position['tradeId'], amount=position['amountK'])
                except Exception as e:
                    print("  Error Closing Trade.")
                    print(e)
                else:
                    print("  Trade Closed Successfully.")
                    
def countOpenTrades(BuySell=None):
    openpositions = con.get_open_positions(kind='list')
    isbuy = True
    counter = 0
    if BuySell == "S":
        isbuy = False
    for position in openpositions:
        if position['currency'] == symbol:
            if BuySell is None or position['isBuy'] == isbuy:
                counter+=1
    return counter

# %%
Prepare() # Initialize strategy
StrategyHeartBeat() # Run strategy
# Out:
# Requesting Initial Price Data...
#                      bidopen  bidclose  bidhigh   bidlow  askopen  askclose  \
# date
# 2019-06-11 20:40:00  1.13265   1.13261  1.13269  1.13261  1.13277   1.13272
# 2019-06-11 20:45:00  1.13261   1.13253  1.13261  1.13251  1.13272   1.13266
# 2019-06-11 20:50:00  1.13253   1.13241  1.13253  1.13241  1.13266   1.13253
# 2019-06-11 20:55:00  1.13242   1.13253  1.13256  1.13242  1.13254   1.13269
# 2019-06-11 21:00:00  1.13252   1.13261  1.13273  1.13251  1.13269   1.13283
#
#                      askhigh   asklow  tickqty
# date
# 2019-06-11 20:40:00  1.13279  1.13271       80
# 2019-06-11 20:45:00  1.13273  1.13263      166
# 2019-06-11 20:50:00  1.13266  1.13252      174
# 2019-06-11 20:55:00  1.13272  1.13254      204
# 2019-06-11 21:00:00  1.13291  1.13267       85
# Initial Price Data Received..
# No updated prices found, trying again in 10 seconds...
# No updated prices found, trying again in 10 seconds...
# No updated prices found, trying again in 10 seconds...
# 2019-06-12 01:15:01.913337    m5 Bar Closed - Running Update Function...
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   # This is added back by InteractiveShellApp.init_path()
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 20:45:00 2019-06-11 20:45:00   1.132595        1.132680
# 2019-06-11 20:50:00 2019-06-11 20:50:00   1.132470        1.132612
# 2019-06-11 20:55:00 2019-06-11 20:55:00   1.132610        1.132585
# 2019-06-11 21:00:00 2019-06-11 21:00:00   1.132720        1.132599
# 2019-06-11 21:05:00 2019-06-11 21:05:00   1.132775        1.132644
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 20:45:00        1.132706 -29681.240202               0
# 2019-06-11 20:50:00        1.132638 -23345.205295               0
# 2019-06-11 20:55:00        1.132612 -22168.819465               0
# 2019-06-11 21:00:00        1.132612 -23423.682508               0
# 2019-06-11 21:05:00        1.132634 -22746.012713               0
# 2019-06-12 01:15:04.566142	 m5 Update Function Completed.
#
# 2019-06-12 01:20:02.187245    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 20:50:00 2019-06-11 20:50:00   1.132470        1.132612
# 2019-06-11 20:55:00 2019-06-11 20:55:00   1.132610        1.132585
# 2019-06-11 21:00:00 2019-06-11 21:00:00   1.132720        1.132599
# 2019-06-11 21:05:00 2019-06-11 21:05:00   1.132775        1.132644
# 2019-06-11 21:10:00 2019-06-11 21:10:00   1.132845        1.132737
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 20:50:00        1.132638 -23345.205295               0
# 2019-06-11 20:55:00        1.132612 -22168.819465               0
# 2019-06-11 21:00:00        1.132612 -23423.682508               0
# 2019-06-11 21:05:00        1.132634 -22746.012713               0
# 2019-06-11 21:10:00        1.132684  11932.032725               1
#   BUY SIGNAL!
#   Opening Buy Trade...
#   Trade Opened Successfully.
# 2019-06-12 01:20:07.684218	 m5 Update Function Completed.
#
# 2019-06-12 01:25:02.251139    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 20:55:00 2019-06-11 20:55:00   1.132610        1.132585
# 2019-06-11 21:00:00 2019-06-11 21:00:00   1.132720        1.132599
# 2019-06-11 21:05:00 2019-06-11 21:05:00   1.132775        1.132644
# 2019-06-11 21:10:00 2019-06-11 21:10:00   1.132845        1.132737
# 2019-06-11 21:15:00 2019-06-11 21:15:00   1.132700        1.132760
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 20:55:00        1.132612 -22168.819465               0
# 2019-06-11 21:00:00        1.132612 -23423.682508               0
# 2019-06-11 21:05:00        1.132634 -22746.012713               0
# 2019-06-11 21:10:00        1.132684  11932.032725               1
# 2019-06-11 21:15:00        1.132730  22287.126488               0
# 2019-06-12 01:25:04.880677	 m5 Update Function Completed.
#
# 2019-06-12 01:30:01.385633    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 21:00:00 2019-06-11 21:00:00   1.132720        1.132599
# 2019-06-11 21:05:00 2019-06-11 21:05:00   1.132775        1.132644
# 2019-06-11 21:10:00 2019-06-11 21:10:00   1.132845        1.132737
# 2019-06-11 21:15:00 2019-06-11 21:15:00   1.132700        1.132760
# 2019-06-11 21:20:00 2019-06-11 21:20:00   1.132655        1.132744
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 21:00:00        1.132612 -23423.682508               0
# 2019-06-11 21:05:00        1.132634 -22746.012713               0
# 2019-06-11 21:10:00        1.132684  11932.032725               1
# 2019-06-11 21:15:00        1.132730  22287.126488               0
# 2019-06-11 21:20:00        1.132739  22340.452613               0
# 2019-06-12 01:30:04.101872	 m5 Update Function Completed.
#
# 2019-06-12 01:35:01.572127    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 21:05:00 2019-06-11 21:05:00   1.132775        1.132644
# 2019-06-11 21:10:00 2019-06-11 21:10:00   1.132845        1.132737
# 2019-06-11 21:15:00 2019-06-11 21:15:00   1.132700        1.132760
# 2019-06-11 21:20:00 2019-06-11 21:20:00   1.132655        1.132744
# 2019-06-11 21:25:00 2019-06-11 21:25:00   1.132705        1.132726
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 21:05:00        1.132634 -22746.012713               0
# 2019-06-11 21:10:00        1.132684  11932.032725               1
# 2019-06-11 21:15:00        1.132730  22287.126488               0
# 2019-06-11 21:20:00        1.132739  22340.452613               0
# 2019-06-11 21:25:00        1.132736  22848.076160               0
# 2019-06-12 01:35:04.293766	 m5 Update Function Completed.
#
# 2019-06-12 01:40:01.803011    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 21:10:00 2019-06-11 21:10:00   1.132845        1.132737
# 2019-06-11 21:15:00 2019-06-11 21:15:00   1.132700        1.132760
# 2019-06-11 21:20:00 2019-06-11 21:20:00   1.132655        1.132744
# 2019-06-11 21:25:00 2019-06-11 21:25:00   1.132705        1.132726
# 2019-06-11 21:30:00 2019-06-11 21:30:00   1.132735        1.132699
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 21:10:00        1.132684  11932.032725               1
# 2019-06-11 21:15:00        1.132730  22287.126488               0
# 2019-06-11 21:20:00        1.132739  22340.452613               0
# 2019-06-11 21:25:00        1.132736  22848.076160               0
# 2019-06-11 21:30:00        1.132728  12844.909610               0
# 2019-06-12 01:40:04.516146	 m5 Update Function Completed.
#
# 2019-06-12 01:45:02.254329    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 21:15:00 2019-06-11 21:15:00   1.132700        1.132760
# 2019-06-11 21:20:00 2019-06-11 21:20:00   1.132655        1.132744
# 2019-06-11 21:25:00 2019-06-11 21:25:00   1.132705        1.132726
# 2019-06-11 21:30:00 2019-06-11 21:30:00   1.132735        1.132699
# 2019-06-11 21:35:00 2019-06-11 21:35:00   1.132725        1.132705
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 21:15:00        1.132730  22287.126488               0
# 2019-06-11 21:20:00        1.132739  22340.452613               0
# 2019-06-11 21:25:00        1.132736  22848.076160               0
# 2019-06-11 21:30:00        1.132728  12844.909610               0
# 2019-06-11 21:35:00        1.132704 -66180.233109              -1
#   SELL SIGNAL!
#   Closing Buy Trade(s)...
#   Closing tradeID: 207973527
#   Trade Closed Successfully.
#   Opening Sell Trade...
#   Trade Opened Successfully.
# 2019-06-12 01:45:10.743815	 m5 Update Function Completed.
#
# 2019-06-12 01:50:02.288630    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 21:20:00 2019-06-11 21:20:00   1.132655        1.132744
# 2019-06-11 21:25:00 2019-06-11 21:25:00   1.132705        1.132726
# 2019-06-11 21:30:00 2019-06-11 21:30:00   1.132735        1.132699
# 2019-06-11 21:35:00 2019-06-11 21:35:00   1.132725        1.132705
# 2019-06-11 21:40:00 2019-06-11 21:40:00   1.132735        1.132725
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 21:20:00        1.132739  22340.452613               0
# 2019-06-11 21:25:00        1.132736  22848.076160               0
# 2019-06-11 21:30:00        1.132728  12844.909610               0
# 2019-06-11 21:35:00        1.132704 -66180.233109              -1
# 2019-06-11 21:40:00        1.132711 -60041.204748               0
# 2019-06-12 01:50:05.032279	 m5 Update Function Completed.
# 2019-06-12 01:55:01.569840    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 21:25:00 2019-06-11 21:25:00   1.132705        1.132726
# 2019-06-11 21:30:00 2019-06-11 21:30:00   1.132735        1.132699
# 2019-06-11 21:35:00 2019-06-11 21:35:00   1.132725        1.132705
# 2019-06-11 21:40:00 2019-06-11 21:40:00   1.132735        1.132725
# 2019-06-11 21:45:00 2019-06-11 21:45:00   1.132720        1.132729
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 21:25:00        1.132736  22848.076160               0
# 2019-06-11 21:30:00        1.132728  12844.909610               0
# 2019-06-11 21:35:00        1.132704 -66180.233109              -1
# 2019-06-11 21:40:00        1.132711 -60041.204748               0
# 2019-06-11 21:45:00        1.132724 -26423.690206               0
# 2019-06-12 01:55:04.151249	 m5 Update Function Completed.
#
# 2019-06-12 02:00:01.786065    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 21:30:00 2019-06-11 21:30:00   1.132735        1.132699
# 2019-06-11 21:35:00 2019-06-11 21:35:00   1.132725        1.132705
# 2019-06-11 21:40:00 2019-06-11 21:40:00   1.132735        1.132725
# 2019-06-11 21:45:00 2019-06-11 21:45:00   1.132720        1.132729
# 2019-06-11 21:50:00 2019-06-11 21:50:00   1.132700        1.132720
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 21:30:00        1.132728  12844.909610               0
# 2019-06-11 21:35:00        1.132704 -66180.233109              -1
# 2019-06-11 21:40:00        1.132711 -60041.204748               0
# 2019-06-11 21:45:00        1.132724 -26423.690205               0
# 2019-06-11 21:50:00        1.132723  50926.237788               1
#   BUY SIGNAL!
#  Closing Sell Trade(s)...
#   Closing tradeID: 207973940
#   Trade Closed Successfully.
#   Opening Buy Trade...
#   Trade Opened Successfully.
# 2019-06-12 02:00:10.326325	 m5 Update Function Completed.
#
# 2019-06-12 02:05:01.797833    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 21:35:00 2019-06-11 21:35:00   1.132725        1.132705
# 2019-06-11 21:40:00 2019-06-11 21:40:00   1.132735        1.132725
# 2019-06-11 21:45:00 2019-06-11 21:45:00   1.132720        1.132729
# 2019-06-11 21:50:00 2019-06-11 21:50:00   1.132700        1.132720
# 2019-06-11 21:55:00 2019-06-11 21:55:00   1.132740        1.132724
#
#                      mid_close_mva5          slope  changeDetected
# date
# 2019-06-11 21:35:00        1.132704  -66180.233109              -1
# 2019-06-11 21:40:00        1.132711  -60041.204748               0
# 2019-06-11 21:45:00        1.132724  -26423.690205               0
# 2019-06-11 21:50:00        1.132723   50926.237788               1
# 2019-06-11 21:55:00        1.132724  118423.855165               0
# 2019-06-12 02:05:04.346676	 m5 Update Function Completed.
#
# 2019-06-12 02:10:01.844561    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 21:40:00 2019-06-11 21:40:00   1.132735        1.132725
# 2019-06-11 21:45:00 2019-06-11 21:45:00   1.132720        1.132729
# 2019-06-11 21:50:00 2019-06-11 21:50:00   1.132700        1.132720
# 2019-06-11 21:55:00 2019-06-11 21:55:00   1.132740        1.132724
# 2019-06-11 22:00:00 2019-06-11 22:00:00   1.132760        1.132730
#
#                      mid_close_mva5          slope  changeDetected
# date
# 2019-06-11 21:40:00        1.132711  -60041.204748               0
# 2019-06-11 21:45:00        1.132724  -26423.690205               0
# 2019-06-11 21:50:00        1.132723   50926.237788               1
# 2019-06-11 21:55:00        1.132724  118423.855165               0
# 2019-06-11 22:00:00        1.132731  135678.391961               0
# 2019-06-12 02:10:04.526730	 m5 Update Function Completed.
#
# 2019-06-12 02:15:02.268558    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 21:45:00 2019-06-11 21:45:00   1.132720        1.132729
# 2019-06-11 21:50:00 2019-06-11 21:50:00   1.132700        1.132720
# 2019-06-11 21:55:00 2019-06-11 21:55:00   1.132740        1.132724
# 2019-06-11 22:00:00 2019-06-11 22:00:00   1.132760        1.132730
# 2019-06-11 22:05:00 2019-06-11 22:05:00   1.132795        1.132749
#
#                      mid_close_mva5          slope  changeDetected
# date
# 2019-06-11 21:45:00        1.132724  -26423.690205               0
# 2019-06-11 21:50:00        1.132723   50926.237788               1
# 2019-06-11 21:55:00        1.132724  118423.855165               0
# 2019-06-11 22:00:00        1.132731  135678.391961               0
# 2019-06-11 22:05:00        1.132743  122610.015172               0
# 2019-06-12 02:15:04.791307	 m5 Update Function Completed.
#
# 2019-06-12 02:20:01.501171    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 21:50:00 2019-06-11 21:50:00   1.132700        1.132720
# 2019-06-11 21:55:00 2019-06-11 21:55:00   1.132740        1.132724
# 2019-06-11 22:00:00 2019-06-11 22:00:00   1.132760        1.132730
# 2019-06-11 22:05:00 2019-06-11 22:05:00   1.132795        1.132749
# 2019-06-11 22:10:00 2019-06-11 22:10:00   1.132745        1.132760
#
#                      mid_close_mva5          slope  changeDetected
# date
# 2019-06-11 21:50:00        1.132723   50926.237788               1
# 2019-06-11 21:55:00        1.132724  118423.855165               0
# 2019-06-11 22:00:00        1.132731  135678.391961               0
# 2019-06-11 22:05:00        1.132743  122610.015172               0
# 2019-06-11 22:10:00        1.132748  101165.007413               0
# 2019-06-12 02:20:04.005956	 m5 Update Function Completed.
#
# 2019-06-12 02:25:01.792814    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 21:55:00 2019-06-11 21:55:00   1.132740        1.132724
# 2019-06-11 22:00:00 2019-06-11 22:00:00   1.132760        1.132730
# 2019-06-11 22:05:00 2019-06-11 22:05:00   1.132795        1.132749
# 2019-06-11 22:10:00 2019-06-11 22:10:00   1.132745        1.132760
# 2019-06-11 22:15:00 2019-06-11 22:15:00   1.132675        1.132744
#
#                      mid_close_mva5          slope  changeDetected
# date
# 2019-06-11 21:55:00        1.132724  118423.855165               0
# 2019-06-11 22:00:00        1.132731  135678.391961               0
# 2019-06-11 22:05:00        1.132743  122610.015172               0
# 2019-06-11 22:10:00        1.132748  101165.007413               0
# 2019-06-11 22:15:00        1.132743  100659.995742               0
# 2019-06-12 02:25:04.323005	 m5 Update Function Completed.
#
# 2019-06-12 02:30:02.049458    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 22:00:00 2019-06-11 22:00:00   1.132760        1.132730
# 2019-06-11 22:05:00 2019-06-11 22:05:00   1.132795        1.132749
# 2019-06-11 22:10:00 2019-06-11 22:10:00   1.132745        1.132760
# 2019-06-11 22:15:00 2019-06-11 22:15:00   1.132675        1.132744
# 2019-06-11 22:20:00 2019-06-11 22:20:00   1.132780        1.132749
#
#                      mid_close_mva5          slope  changeDetected
# date
# 2019-06-11 22:00:00        1.132731  135678.391961               0
# 2019-06-11 22:05:00        1.132743  122610.015172               0
# 2019-06-11 22:10:00        1.132748  101165.007413               0
# 2019-06-11 22:15:00        1.132743  100659.995742               0
# 2019-06-11 22:20:00        1.132751   99300.699300               0
# 2019-06-12 02:30:04.610907	 m5 Update Function Completed.
# 2019-06-12 02:35:02.252798    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 22:05:00 2019-06-11 22:05:00   1.132795        1.132749
# 2019-06-11 22:10:00 2019-06-11 22:10:00   1.132745        1.132760
# 2019-06-11 22:15:00 2019-06-11 22:15:00   1.132675        1.132744
# 2019-06-11 22:20:00 2019-06-11 22:20:00   1.132780        1.132749
# 2019-06-11 22:25:00 2019-06-11 22:25:00   1.132785        1.132746
#
#                      mid_close_mva5          slope  changeDetected
# date
# 2019-06-11 22:05:00        1.132743  122610.015172               0
# 2019-06-11 22:10:00        1.132748  101165.007413               0
# 2019-06-11 22:15:00        1.132743  100659.995742               0
# 2019-06-11 22:20:00        1.132751   99300.699300               0
# 2019-06-11 22:25:00        1.132756   68874.172185               0
# 2019-06-12 02:35:04.761325	 m5 Update Function Completed.
#
# 2019-06-12 02:40:01.394767    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 22:10:00 2019-06-11 22:10:00   1.132745        1.132760
# 2019-06-11 22:15:00 2019-06-11 22:15:00   1.132675        1.132744
# 2019-06-11 22:20:00 2019-06-11 22:20:00   1.132780        1.132749
# 2019-06-11 22:25:00 2019-06-11 22:25:00   1.132785        1.132746
# 2019-06-11 22:30:00 2019-06-11 22:30:00   1.132790        1.132757
#
#                      mid_close_mva5          slope  changeDetected
# date
# 2019-06-11 22:10:00        1.132748  101165.007413               0
# 2019-06-11 22:15:00        1.132743  100659.995742               0
# 2019-06-11 22:20:00        1.132751   99300.699300               0
# 2019-06-11 22:25:00        1.132756   68874.172185               0
# 2019-06-11 22:30:00        1.132755   17999.999992               0
# 2019-06-12 02:40:04.006155	 m5 Update Function Completed.
#
# 2019-06-12 02:45:01.705167    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 22:15:00 2019-06-11 22:15:00   1.132675        1.132744
# 2019-06-11 22:20:00 2019-06-11 22:20:00   1.132780        1.132749
# 2019-06-11 22:25:00 2019-06-11 22:25:00   1.132785        1.132746
# 2019-06-11 22:30:00 2019-06-11 22:30:00   1.132790        1.132757
# 2019-06-11 22:35:00 2019-06-11 22:35:00   1.132845        1.132800
#
#                      mid_close_mva5          slope  changeDetected
# date
# 2019-06-11 22:15:00        1.132743  100659.995742               0
# 2019-06-11 22:20:00        1.132751   99300.699300               0
# 2019-06-11 22:25:00        1.132756   68874.172185               0
# 2019-06-11 22:30:00        1.132755   17999.999992               0
# 2019-06-11 22:35:00        1.132775   54669.051878               0
# 2019-06-12 02:45:04.210668	 m5 Update Function Completed.
#
# 2019-06-12 02:50:03.162836    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 22:20:00 2019-06-11 22:20:00   1.132780        1.132749
# 2019-06-11 22:25:00 2019-06-11 22:25:00   1.132785        1.132746
# 2019-06-11 22:30:00 2019-06-11 22:30:00   1.132790        1.132757
# 2019-06-11 22:35:00 2019-06-11 22:35:00   1.132845        1.132800
# 2019-06-11 22:40:00 2019-06-11 22:40:00   1.132845        1.132816
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 22:20:00        1.132751  99300.699300               0
# 2019-06-11 22:25:00        1.132756  68874.172185               0
# 2019-06-11 22:30:00        1.132755  17999.999992               0
# 2019-06-11 22:35:00        1.132775  54669.051878               0
# 2019-06-11 22:40:00        1.132809  53929.712460               0
# 2019-06-12 02:50:05.702841	 m5 Update Function Completed.
#
# 2019-06-12 02:55:02.410263    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 22:25:00 2019-06-11 22:25:00   1.132785        1.132746
# 2019-06-11 22:30:00 2019-06-11 22:30:00   1.132790        1.132757
# 2019-06-11 22:35:00 2019-06-11 22:35:00   1.132845        1.132800
# 2019-06-11 22:40:00 2019-06-11 22:40:00   1.132845        1.132816
# 2019-06-11 22:45:00 2019-06-11 22:45:00   1.132840        1.132830
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 22:25:00        1.132756  68874.172185               0
# 2019-06-11 22:30:00        1.132755  17999.999992               0
# 2019-06-11 22:35:00        1.132775  54669.051878               0
# 2019-06-11 22:40:00        1.132809  53929.712460               0
# 2019-06-11 22:45:00        1.132821  48599.423631               0
# 2019-06-12 02:55:04.890025	 m5 Update Function Completed.
#
# 2019-06-12 03:00:01.658346    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 22:30:00 2019-06-11 22:30:00   1.132790        1.132757
# 2019-06-11 22:35:00 2019-06-11 22:35:00   1.132845        1.132800
# 2019-06-11 22:40:00 2019-06-11 22:40:00   1.132845        1.132816
# 2019-06-11 22:45:00 2019-06-11 22:45:00   1.132840        1.132830
# 2019-06-11 22:50:00 2019-06-11 22:50:00   1.132775        1.132826
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 22:30:00        1.132755  17999.999992               0
# 2019-06-11 22:35:00        1.132775  54669.051878               0
# 2019-06-11 22:40:00        1.132809  53929.712460               0
# 2019-06-11 22:45:00        1.132821  48599.423631               0
# 2019-06-11 22:50:00        1.132819  49094.210208               0
# 2019-06-12 03:00:04.158316	 m5 Update Function Completed.
#
# 2019-06-12 03:05:01.836569    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 22:35:00 2019-06-11 22:35:00   1.132845        1.132800
# 2019-06-11 22:40:00 2019-06-11 22:40:00   1.132845        1.132816
# 2019-06-11 22:45:00 2019-06-11 22:45:00   1.132840        1.132830
# 2019-06-11 22:50:00 2019-06-11 22:50:00   1.132775        1.132826
# 2019-06-11 22:55:00 2019-06-11 22:55:00   1.132780        1.132810
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 22:35:00        1.132775  54669.051877               0
# 2019-06-11 22:40:00        1.132809  53929.712460               0
# 2019-06-11 22:45:00        1.132821  48599.423631               0
# 2019-06-11 22:50:00        1.132819  49094.210208               0
# 2019-06-11 22:55:00        1.132817  50820.161050               0
# 2019-06-12 03:05:04.389661	 m5 Update Function Completed.
#
# 2019-06-12 03:10:02.268513    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 22:40:00 2019-06-11 22:40:00   1.132845        1.132816
# 2019-06-11 22:45:00 2019-06-11 22:45:00   1.132840        1.132830
# 2019-06-11 22:50:00 2019-06-11 22:50:00   1.132775        1.132826
# 2019-06-11 22:55:00 2019-06-11 22:55:00   1.132780        1.132810
# 2019-06-11 23:00:00 2019-06-11 23:00:00   1.132795        1.132797
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 22:40:00        1.132809  53929.712460               0
# 2019-06-11 22:45:00        1.132821  48599.423631               0
# 2019-06-11 22:50:00        1.132819  49094.210208               0
# 2019-06-11 22:55:00        1.132817  50820.161050               0
# 2019-06-11 23:00:00        1.132807 -19603.267210              -1
#   SELL SIGNAL!
#   Closing Buy Trade(s)...
#   Closing tradeID: 207973963
#   Trade Closed Successfully.
#   Opening Sell Trade...
#   Trade Opened Successfully.
# 2019-06-12 03:10:11.391456	 m5 Update Function Completed.
#
# 2019-06-12 03:15:01.861551    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 22:45:00 2019-06-11 22:45:00   1.132840        1.132830
# 2019-06-11 22:50:00 2019-06-11 22:50:00   1.132775        1.132826
# 2019-06-11 22:55:00 2019-06-11 22:55:00   1.132780        1.132810
# 2019-06-11 23:00:00 2019-06-11 23:00:00   1.132795        1.132797
# 2019-06-11 23:05:00 2019-06-11 23:05:00   1.132735        1.132771
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 22:45:00        1.132821  48599.423631               0
# 2019-06-11 22:50:00        1.132819  49094.210208               0
# 2019-06-11 22:55:00        1.132817  50820.161050               0
# 2019-06-11 23:00:00        1.132807 -19603.267210              -1
# 2019-06-11 23:05:00        1.132785 -72130.420317               0
# 2019-06-12 03:15:04.392263	 m5 Update Function Completed.
#
# 2019-06-12 03:20:01.981299    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 22:50:00 2019-06-11 22:50:00   1.132775        1.132826
# 2019-06-11 22:55:00 2019-06-11 22:55:00   1.132780        1.132810
# 2019-06-11 23:00:00 2019-06-11 23:00:00   1.132795        1.132797
# 2019-06-11 23:05:00 2019-06-11 23:05:00   1.132735        1.132771
# 2019-06-11 23:10:00 2019-06-11 23:10:00   1.132750        1.132765
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 22:50:00        1.132819  49094.210208               0
# 2019-06-11 22:55:00        1.132817  50820.161050               0
# 2019-06-11 23:00:00        1.132807 -19603.267210              -1
# 2019-06-11 23:05:00        1.132785 -72130.420317               0
# 2019-06-11 23:10:00        1.132767 -67055.879900               0
# 2019-06-12 03:20:04.574385	 m5 Update Function Completed.
#
# 2019-06-12 03:25:02.333146    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 22:55:00 2019-06-11 22:55:00   1.132780        1.132810
# 2019-06-11 23:00:00 2019-06-11 23:00:00   1.132795        1.132797
# 2019-06-11 23:05:00 2019-06-11 23:05:00   1.132735        1.132771
# 2019-06-11 23:10:00 2019-06-11 23:10:00   1.132750        1.132765
# 2019-06-11 23:15:00 2019-06-11 23:15:00   1.132720        1.132750
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 22:55:00        1.132817  50820.161050               0
# 2019-06-11 23:00:00        1.132807 -19603.267210              -1
# 2019-06-11 23:05:00        1.132785 -72130.420317               0
# 2019-06-11 23:10:00        1.132767 -67055.879900               0
# 2019-06-11 23:15:00        1.132756 -63373.083476               0
# 2019-06-12 03:25:04.819095	 m5 Update Function Completed.
#
# 2019-06-12 03:30:01.530091    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 23:00:00 2019-06-11 23:00:00   1.132795        1.132797
# 2019-06-11 23:05:00 2019-06-11 23:05:00   1.132735        1.132771
# 2019-06-11 23:10:00 2019-06-11 23:10:00   1.132750        1.132765
# 2019-06-11 23:15:00 2019-06-11 23:15:00   1.132720        1.132750
# 2019-06-11 23:20:00 2019-06-11 23:20:00   1.132725        1.132732
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 23:00:00        1.132807 -19603.267210              -1
# 2019-06-11 23:05:00        1.132785 -72130.420317               0
# 2019-06-11 23:10:00        1.132767 -67055.879900               0
# 2019-06-11 23:15:00        1.132756 -63373.083476               0
# 2019-06-11 23:20:00        1.132745 -64105.597410               0
# 2019-06-12 03:30:04.067725	 m5 Update Function Completed.
#
# 2019-06-12 03:35:01.864926    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 23:05:00 2019-06-11 23:05:00   1.132735        1.132771
# 2019-06-11 23:10:00 2019-06-11 23:10:00   1.132750        1.132765
# 2019-06-11 23:15:00 2019-06-11 23:15:00   1.132720        1.132750
# 2019-06-11 23:20:00 2019-06-11 23:20:00   1.132725        1.132732
# 2019-06-11 23:25:00 2019-06-11 23:25:00   1.132695        1.132722
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 23:05:00        1.132785 -72130.420317               0
# 2019-06-11 23:10:00        1.132767 -67055.879900               0
# 2019-06-11 23:15:00        1.132756 -63373.083476               0
# 2019-06-11 23:20:00        1.132745 -64105.597410               0
# 2019-06-11 23:25:00        1.132725 -67589.180168               0
# 2019-06-12 03:35:04.382482	 m5 Update Function Completed.
#
# 2019-06-12 03:40:01.844669    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 23:10:00 2019-06-11 23:10:00   1.132750        1.132765
# 2019-06-11 23:15:00 2019-06-11 23:15:00   1.132720        1.132750
# 2019-06-11 23:20:00 2019-06-11 23:20:00   1.132725        1.132732
# 2019-06-11 23:25:00 2019-06-11 23:25:00   1.132695        1.132722
# 2019-06-11 23:30:00 2019-06-11 23:30:00   1.132710        1.132712
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 23:10:00        1.132767 -67055.879900               0
# 2019-06-11 23:15:00        1.132756 -63373.083476               0
# 2019-06-11 23:20:00        1.132745 -64105.597410               0
# 2019-06-11 23:25:00        1.132725 -67589.180168               0
# 2019-06-11 23:30:00        1.132720 -78662.806985               0
# 2019-06-12 03:40:04.372415	 m5 Update Function Completed.
#
# 2019-06-12 03:45:01.908516    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 23:15:00 2019-06-11 23:15:00   1.132720        1.132750
# 2019-06-11 23:20:00 2019-06-11 23:20:00   1.132725        1.132732
# 2019-06-11 23:25:00 2019-06-11 23:25:00   1.132695        1.132722
# 2019-06-11 23:30:00 2019-06-11 23:30:00   1.132710        1.132712
# 2019-06-11 23:35:00 2019-06-11 23:35:00   1.132735        1.132716
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 23:15:00        1.132756 -63373.083476               0
# 2019-06-11 23:20:00        1.132745 -64105.597410               0
# 2019-06-11 23:25:00        1.132725 -67589.180168               0
# 2019-06-11 23:30:00        1.132720 -78662.806985               0
# 2019-06-11 23:35:00        1.132717 -86208.164767               0
# 2019-06-12 03:45:04.513903	 m5 Update Function Completed.
#
# 2019-06-12 03:50:02.735918    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 23:20:00 2019-06-11 23:20:00   1.132725        1.132732
# 2019-06-11 23:25:00 2019-06-11 23:25:00   1.132695        1.132722
# 2019-06-11 23:30:00 2019-06-11 23:30:00   1.132710        1.132712
# 2019-06-11 23:35:00 2019-06-11 23:35:00   1.132735        1.132716
# 2019-06-11 23:40:00 2019-06-11 23:40:00   1.132775        1.132729
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 23:20:00        1.132745 -64105.597410               0
# 2019-06-11 23:25:00        1.132725 -67589.180168               0
# 2019-06-11 23:30:00        1.132720 -78662.806985               0
# 2019-06-11 23:35:00        1.132717 -86208.164767               0
# 2019-06-11 23:40:00        1.132728 -90825.688074               0
# 2019-06-12 03:50:05.267936	 m5 Update Function Completed.
# 2019-06-12 03:55:01.975473    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 23:25:00 2019-06-11 23:25:00   1.132695        1.132722
# 2019-06-11 23:30:00 2019-06-11 23:30:00   1.132710        1.132712
# 2019-06-11 23:35:00 2019-06-11 23:35:00   1.132735        1.132716
# 2019-06-11 23:40:00 2019-06-11 23:40:00   1.132775        1.132729
# 2019-06-11 23:45:00 2019-06-11 23:45:00   1.132845        1.132766
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 23:25:00        1.132725 -67589.180168               0
# 2019-06-11 23:30:00        1.132720 -78662.806985               0
# 2019-06-11 23:35:00        1.132717 -86208.164767               0
# 2019-06-11 23:40:00        1.132728 -90825.688074               0
# 2019-06-11 23:45:00        1.132752  51049.631586               1
#   BUY SIGNAL!
#  Closing Sell Trade(s)...
#   Closing tradeID: 207974151
#   Trade Closed Successfully.
#   Opening Buy Trade...
#   Trade Opened Successfully.
# 2019-06-12 03:55:12.990831	 m5 Update Function Completed.
#
# 2019-06-12 04:00:01.588061    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 23:30:00 2019-06-11 23:30:00   1.132710        1.132712
# 2019-06-11 23:35:00 2019-06-11 23:35:00   1.132735        1.132716
# 2019-06-11 23:40:00 2019-06-11 23:40:00   1.132775        1.132729
# 2019-06-11 23:45:00 2019-06-11 23:45:00   1.132845        1.132766
# 2019-06-11 23:50:00 2019-06-11 23:50:00   1.132885        1.132810
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 23:30:00        1.132720 -78662.806985               0
# 2019-06-11 23:35:00        1.132717 -86208.164767               0
# 2019-06-11 23:40:00        1.132728 -90825.688075               0
# 2019-06-11 23:45:00        1.132752  51049.631586               1
# 2019-06-11 23:50:00        1.132790  41876.895629               0
# 2019-06-12 04:00:04.102678	 m5 Update Function Completed.
#
# 2019-06-12 04:05:06.545492    m5 Bar Closed - Running Update Function...
#                                    date  mid_close  mid_close_mva4  \
# date
# 2019-06-11 23:35:00 2019-06-11 23:35:00   1.132735        1.132716
# 2019-06-11 23:40:00 2019-06-11 23:40:00   1.132775        1.132729
# 2019-06-11 23:45:00 2019-06-11 23:45:00   1.132845        1.132766
# 2019-06-11 23:50:00 2019-06-11 23:50:00   1.132885        1.132810
# 2019-06-11 23:55:00 2019-06-11 23:55:00   1.132960        1.132866
#
#                      mid_close_mva5         slope  changeDetected
# date
# 2019-06-11 23:35:00        1.132717 -86208.164767               0
# 2019-06-11 23:40:00        1.132728 -90825.688074               0
# 2019-06-11 23:45:00        1.132752  51049.631586               1
# 2019-06-11 23:50:00        1.132790  41876.895629               0
# 2019-06-11 23:55:00        1.132840  29064.587973               0
# 2019-06-12 04:05:09.093400	 m5 Update Function Completed.
